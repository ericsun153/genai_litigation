# %%
import pandas as pd

# %%
df = pd.read_csv("data_nlp/enriched_copyright_cases.csv")
df.head()
# Out:
#                                      case_name_final  \
# 0                           GPNE Corp. v. Apple Inc.
# 1       Williamson v. Haywood County Justice Complex
# 2  Halcyon Horizons, Incorporated v. Delphi Behav...
# 3                Synopsys, Inc. v. Real Intent, Inc.
# 4                          Apple Inc. v. Rivos, Inc.
#
#                                            case_name  year_final  \
# 0  Andersen v. Stability AI Ltd., 2025 U.S. Dist....        2012
# 1    In re Openai, Inc., 2026 U.S. Dist. LEXIS 76901        2014
# 2     Hollis v. Render, 2025 U.S. Dist. LEXIS 139005        2017
# 3  Synopsys, Inc. v. Real Intent, Inc., 2024 U.S....        2020
# 4  Flexport, Inc. v. Freightmate AI, Inc., 2025 U...        2022
#
#                        court_final         judge_final docket_number_final  \
# 0  District Court, N.D. California     Lucy Haeran Koh       5:12-cv-02885
# 1   District Court, W.D. Tennessee     James Dale Todd       1:14-cv-01254
# ...

# %%
df1 = pd.read_csv("data_nlp/final_ai_copyright_nlp_output.csv")
df1.head()
# Out:
#                                      case_name_final  \
# 0                           GPNE Corp. v. Apple Inc.
# 1       Williamson v. Haywood County Justice Complex
# 2  Halcyon Horizons, Incorporated v. Delphi Behav...
# 3                Synopsys, Inc. v. Real Intent, Inc.
# 4                          Apple Inc. v. Rivos, Inc.
#
#                                            case_name  year_final  \
# 0  Andersen v. Stability AI Ltd., 2025 U.S. Dist....        2012
# 1    In re Openai, Inc., 2026 U.S. Dist. LEXIS 76901        2014
# 2     Hollis v. Render, 2025 U.S. Dist. LEXIS 139005        2017
# 3  Synopsys, Inc. v. Real Intent, Inc., 2024 U.S....        2020
# 4  Flexport, Inc. v. Freightmate AI, Inc., 2025 U...        2022
#
#                        court_final         judge_final docket_number_final  \
# 0  District Court, N.D. California     Lucy Haeran Koh       5:12-cv-02885
# 1   District Court, W.D. Tennessee     James Dale Todd       1:14-cv-01254
# ...

# %%
df2 = pd.read_csv("data_nlp/ai_copyright_case_summary_for_paper.csv")
df2.head()
# Out:
#                                      case_name_final  year_final  \
# 0                           GPNE Corp. v. Apple Inc.        2012
# 1       Williamson v. Haywood County Justice Complex        2014
# 2  Halcyon Horizons, Incorporated v. Delphi Behav...        2017
# 3                Synopsys, Inc. v. Real Intent, Inc.        2020
# 4                          Apple Inc. v. Rivos, Inc.        2022
#
#                        court_final         judge_final docket_number_final  \
# 0  District Court, N.D. California     Lucy Haeran Koh       5:12-cv-02885
# 1   District Court, W.D. Tennessee     James Dale Todd       1:14-cv-01254
# 2  District Court, N.D. California    Jon Steven Tigar       4:17-cv-00756
# 3  District Court, N.D. California  Edward John Davila       5:20-cv-02819
# 4  District Court, N.D. California      P. Casey Pitts       5:22-cv-02637
#
#    recap_found  opinion_found              data_source_for_text  \
# ...
